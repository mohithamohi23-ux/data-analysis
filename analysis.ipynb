# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("sales.csv")  # loads your CSV file
df.head()
# Out:
#     Product  Sales Region
# 0    Laptop    500  North
# 1     Phone    300  South
# 2    Tablet    200   East
# 3   Monitor    450   West
# 4  Keyboard    120  North

# %%
df.shape
# Out:
# (6, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Product  6 non-null      object
#  1   Sales    6 non-null      int64
#  2   Region   6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 276.0+ bytes

# %%
df.isna().sum()
# Out:
# Product    0
# Sales      0
# Region     0
# dtype: int64

# %%
df.describe()
# Out:
#             Sales
# count    6.000000
# mean   275.000000
# std    172.945078
# min     80.000000
# 25%    140.000000
# 50%    250.000000
# 75%    412.500000
# max    500.000000

# %%
product_sales = df.groupby("Product")["Sales"].sum()
product_sales
# Out:
# Product
# Keyboard    120
# Laptop      500
# Monitor     450
# Mouse        80
# Phone       300
# Tablet      200
# Name: Sales, dtype: int64

# %%
region_sales = df.groupby("Region")["Sales"].sum()
region_sales
# Out:
# Region
# East     200
# North    620
# South    380
# West     450
# Name: Sales, dtype: int64

# %%
product_sales.plot(kind="bar")
plt.title("Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.show()

# %%
region_sales.plot(kind="bar")
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()
